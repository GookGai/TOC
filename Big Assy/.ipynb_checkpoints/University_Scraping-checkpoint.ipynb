# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup
import re

# %%
url = 'http://kmitl.ac.th/school-engineering'
en_url = 'http://kmitl.ac.th/school-engineering'

# %%
data  = requests.get(url).text
soup = BeautifulSoup(data, 'html.parser')
print(soup.prettify())
# Out:
# <!-- THEME DEBUG -->
# <!-- THEME HOOK: 'html' -->
# <!-- FILE NAME SUGGESTIONS:
#    * html--node--581.html.twig
#    * html--node--%.html.twig
#    * html--node.html.twig
#    x html.html.twig
# -->
# <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/html.html.twig' -->
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <meta charset="utf-8"/>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-41909381-25">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments)};gtag("js", new Date());gtag("config", "UA-41909381-25", {"groups":"default","anonymize_ip":true});
#   </script>
#   <link href="http://kmitl.ac.th/school-engineering" rel="canonical"/>
#   <meta content="หลักสูตรทั้งหมดของคณะ" name="description"/>
#   <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <style>
#    div#sliding-popup, div#sliding-popup .eu-cookie-withdraw-banner, .eu-cookie-withdraw-tab {background: #212529} div#sliding-popup.eu-cookie-withdraw-wrapper { background: transparent; } #sliding-popup h1, #sliding-popup h2, #sliding-popup h3, #sliding-popup p, #sliding-popup label, #sliding-popup div, .eu-cookie-compliance-more-button, .eu-cookie-compliance-secondary-button, .eu-cookie-withdraw-tab { color: #ffffff;} .eu-cookie-withdraw-tab { border-color: #ffffff;}
#   </style>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <link href="/themes/custom/kmitl/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <link href="http://kmitl.ac.th/school-engineering" hreflang="und" rel="alternate"/>
#   <script>
#    window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};
#   </script>
#   <title>
#    School of Engineering | สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง
#   </title>
#   <link href="/sites/default/files/css/css_qSV0Mqtz2j9lDadb8UN6QNGCygwbFJDzA-HOCsTd9f4.css" media="all" rel="stylesheet"/>
#   <link href="https://use.fontawesome.com/releases/v5.13.1/css/all.css" media="all" rel="stylesheet"/>
#   <link href="https://use.fontawesome.com/releases/v5.13.1/css/v4-shims.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_0HUkC0JpTO0TJtpnLpV2bKkSNoSIP1WFNtlsybC700w.css" media="all" rel="stylesheet"/>
#   <link href="https://unpkg.com/aos@2.3.1/dist/aos.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_Fn0He_O-xfuh68LEWaV3VloEV2cUQITFGJgnmQXEvys.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_zi2fJW-fTZejChP5_yWj0djgF1ngBKHVxkonFDnwxvs.css" media="all" rel="stylesheet"/>
#   <link href="//cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_AKLVRyrzv4CfVD48UTu7Wv9hfvj43whD4hxXdt8hakc.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_Y4H_4BqmgyCtG7E7YdseTs2qvy9C34c51kBamDdgark.css" media="print" rel="stylesheet"/>
#  </head>
#  <body class="layout-no-sidebars page-node-581 path-node node--type-landing-page">
#   <a class="visually-hidden focusable skip-link" href="#main-content">
#    Skip to main content
#   </a>
#   <!-- THEME DEBUG -->
#   <!-- THEME HOOK: 'off_canvas_page_wrapper' -->
#   <!-- BEGIN OUTPUT from 'core/modules/system/templates/off-canvas-page-wrapper.html.twig' -->
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <!-- THEME DEBUG -->
#    <!-- THEME HOOK: 'page' -->
#    <!-- FILE NAME SUGGESTIONS:
#    * page--node--landing-page.html.twig
#    x page--landing-page.html.twig
#    * page--node--581.html.twig
#    * page--node--%.html.twig
#    * page--node.html.twig
#    * page.html.twig
# -->
#    <!-- BEGIN OUTPUT from 'themes/custom/kmitl/templates/page--landing-page.html.twig' -->
#    <div id="page-wrapper">
#     <div id="page">
#      <header aria-label="Site header" class="header" id="header" role="banner">
#       <nav class="navbar navbar-expand-lg" id="navbar-top">
#        <div class="container">
#         <!-- THEME DEBUG -->
#         <!-- THEME HOOK: 'region' -->
#         <!-- FILE NAME SUGGESTIONS:
#    * region--top-header.html.twig
#    x region.html.twig
# -->
#         <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/region.html.twig' -->
#         <section class="region region-top-header">
#          <!-- THEME DEBUG -->
#          <!-- THEME HOOK: 'block' -->
#          <!-- FILE NAME SUGGESTIONS:
#    * block--kmitl-branding.html.twig
#    x block--system-branding-block.html.twig
#    * block--system.html.twig
#    * block.html.twig
# -->
#          <!-- BEGIN OUTPUT from 'themes/custom/kmitl/templates/block--system-branding-block.html.twig' -->
#          <div class="kmitl-branding">
#           <a class="navbar-brand" href="/index.php/" rel="home" title="Home">
#            <span class="site-logo">
#             <img alt="Home" class="kmitl-logo" src="/themes/custom/kmitl/logo.svg"/>
#            </span>
#            <div>
#             <div class="kmitl-site_name">
#              สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง
#             </div>
#             <div class="kmitl-site_name-mobile">
#              kmitl
#             </div>
#             <div class="kmitl-site_slogan site-name-slogan">
#              King Mongkut's Institute of Technology Ladkrabang
#             </div>
#            </div>
#           </a>
#          </div>
#          <!-- END OUTPUT from 'themes/custom/kmitl/templates/block--system-branding-block.html.twig' -->
#          <!-- THEME DEBUG -->
#          <!-- THEME HOOK: 'block' -->
#          <!-- FILE NAME SUGGESTIONS:
#    * block--languageswitcher.html.twig
#    * block--language-block--language-interface.html.twig
#    * block--language-block.html.twig
#    * block--language.html.twig
#    x block.html.twig
# -->
#          <!-- BEGIN OUTPUT from 'themes/custom/kmitl/templates/block.html.twig' -->
#          <div class="language-switcher-language-url block block-language block-language-blocklanguage-interface" id="block-languageswitcher" role="navigation">
#           <div class="content">
#            <!-- THEME DEBUG -->
#            <!-- THEME HOOK: 'links__language_block' -->
#            <!-- FILE NAME SUGGESTIONS:
#    x links--language-block.html.twig
#    x links--language-block.html.twig
#    * links.html.twig
# -->
#            <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/navigation/links--language-block.html.twig' -->
#            <nav class="links nav links-inline">
#             <span class="en nav-link is-active" data-drupal-link-system-path="node/581" hreflang="en">
#              <a class="language-link is-active" data-drupal-link-system-path="node/581" href="/school-engineering" hreflang="en">
#               EN
#              </a>
#             </span>
#             <span class="th nav-link" data-drupal-link-system-path="node/581" hreflang="th">
#              <a class="language-link" data-drupal-link-system-path="node/581" href="/th/school-engineering" hreflang="th">
#               TH
#              </a>
#             </span>
#            </nav>
#            <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/navigation/links--language-block.html.twig' -->
#           </div>
#          </div>
#          <!-- END OUTPUT from 'themes/custom/kmitl/templates/block.html.twig' -->
#         </section>
#         <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/region.html.twig' -->
#        </div>
#       </nav>
#       <nav class="navbar navbar-expand-lg" id="navbar-main">
#        <div class="container-lg">
#         <button aria-controls="navbar-collapsible" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler navbar-toggler-right collapsed" data-bs-target="#navbar-collapsible" data-bs-toggle="collapse" type="button">
#          <i class="fas fa-bars">
#          </i>
#         </button>
#         <div class="navbar-collapse collapse justify-content-between" id="navbar-collapsible">
#          <!-- THEME DEBUG -->
#          <!-- THEME HOOK: 'region' -->
#          <!-- FILE NAME SUGGESTIONS:
#    x region--nowrap.html.twig
#    * region--primary-menu.html.twig
#    * region.html.twig
# -->
#          <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/region--nowrap.html.twig' -->
#          <!-- THEME DEBUG -->
#          <!-- THEME HOOK: 'block' -->
#          <!-- FILE NAME SUGGESTIONS:
#    * block--mainnavigation-2.html.twig
#    * block--system-menu-block--main.html.twig
#    x block--system-menu-block.html.twig
#    * block--system.html.twig
#    * block.html.twig
# -->
#          <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/block/block--system-menu-block.html.twig' -->
#          <nav aria-labelledby="block-mainnavigation-2-menu" class="block block-menu navigation menu--main" id="block-mainnavigation-2" role="navigation">
#           <h2 class="visually-hidden" id="block-mainnavigation-2-menu">
#            Main navigation
#           </h2>
#           <!-- THEME DEBUG -->
#           <!-- THEME HOOK: 'menu__main' -->
#           <!-- FILE NAME SUGGESTIONS:
#    x menu--main.html.twig
#    x menu--main.html.twig
#    * menu.html.twig
# -->
#           <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/navigation/menu--main.html.twig' -->
#           <ul class="clearfix nav navbar-nav">
#            <li class="nav-item">
#             <a class="nav-link nav-link--indexphp-" data-drupal-link-system-path="&lt;front&gt;" href="/index.php/">
#              Home
#             </a>
#            </li>
#            <li class="nav-item menu-item--expanded dropdown">
#             <span aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle nav-link-" data-bs-toggle="dropdown">
#              Information for
#             </span>
#             <ul class="dropdown-menu">
#              <li class="dropdown-item">
#               <a class="nav-link--indexphp-parents-and-prospective-students" data-drupal-link-system-path="node/541" href="/index.php/parents-and-prospective-students">
#                Parent and prospective students
#               </a>
#              </li>
#              <li class="dropdown-item">
#               <a class="nav-link--indexphp-current-students" href="/index.php/current-students">
#                Current students
#               </a>
#              </li>
#              <li class="dropdown-item menu-item--expanded dropdown">
#               <span aria-expanded="false" aria-haspopup="true" class="dropdown-toggle nav-link-" data-bs-toggle="dropdown">
#                Staffs
#               </span>
#               <ul class="dropdown-menu">
#                <li class="dropdown-item">
#                 <a class="nav-link-https--wwwitrectorkmitlacth-salary-" href="https://www.itrector.kmitl.ac.th/salary/">
#                  Salary and Payment Records
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link-http--financialkmitlacth-" href="http://financial.kmitl.ac.th/">
#                  3-D Acquirable-Payable Account
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link-https--wwwitrectorkmitlacth-kmitl-personnel-indexphp" href="https://www.itrector.kmitl.ac.th/KMITL_Personnel/index.php">
#                  Staff’s Information System
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link-https--wwwitrectorkmitlacth-vehicle-" href="https://www.itrector.kmitl.ac.th/vehicle/">
#                  Car Reservation System
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link-https--wwwitrectorkmitlacth-meeting-room-" href="https://www.itrector.kmitl.ac.th/meeting_room/">
#                  Request Meeting
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link-https--wwwitrectorkmitlacth-repair" href="https://www.itrector.kmitl.ac.th/repair">
#                  Computer Repair online Service
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </li>
#            <li class="nav-item menu-item--expanded dropdown">
#             <span aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle nav-link-" data-bs-toggle="dropdown">
#              Research
#             </span>
#             <ul class="dropdown-menu">
#              <li class="dropdown-item">
#               <a class="nav-link-http--kriskmitlacth-indexphp" href="http://kris.kmitl.ac.th/index.php">
#                Research
#               </a>
#              </li>
#              <li class="dropdown-item">
#               <a class="nav-link-http--rspgkmitlacth-" href="http://rspg.kmitl.ac.th/">
#                RSPG-KMITL
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="nav-item menu-item--expanded dropdown">
#             <span aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle nav-link-" data-bs-toggle="dropdown">
#              News &amp; Activities
#             </span>
#             <ul class="dropdown-menu">
#              <li class="dropdown-item">
#               <a class="nav-link--indexphp-content-all" data-drupal-link-system-path="content/all" href="/index.php/content/all">
#                KMITL News
#               </a>
#              </li>
#              <li class="dropdown-item">
#               <a class="nav-link--indexphp-procurement" data-drupal-link-system-path="procurement" href="/index.php/procurement">
#                Procurement
#               </a>
#              </li>
#              <li class="dropdown-item">
#               <a class="nav-link-https--wwwkmitlacth-content-allcat40keywords" href="https://www.kmitl.ac.th/content/all?cat=40&amp;keywords=">
#                Press Release
#               </a>
#              </li>
#              <li class="dropdown-item">
#               <a class="nav-link-http--wwwhrkmitlacth-" href="http://www.hr.kmitl.ac.th/">
#                Apply  job News
#               </a>
#              </li>
#              <li class="dropdown-item">
#               <a class="nav-link-https--wwwtci-thaijoorg-indexphp-cast" href="https://www.tci-thaijo.org/index.php/cast">
#                Current Applied  Science and Technology
#               </a>
#              </li>
#              <li class="dropdown-item">
#               <a class="nav-link-http--jmsrkmitlacth-2018-" href="http://jmsr.kmitl.ac.th/2018/">
#                Journal of Multidisciplinary Social Research
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="nav-item menu-item--expanded dropdown">
#             <span aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle nav-link-" data-bs-toggle="dropdown" title="Faculties and Offices in KMITL">
#              Academic Divisions and Offices
#             </span>
#             <ul class="dropdown-menu">
#              <li class="dropdown-item menu-item--expanded dropdown">
#               <span aria-expanded="false" aria-haspopup="true" class="dropdown-toggle nav-link-" data-bs-toggle="dropdown">
#                Campus
#               </span>
#               <ul class="dropdown-menu">
#                <li class="dropdown-item">
#                 <a class="nav-link-http--wwwpcckmitlacth-" href="http://www.pcc.kmitl.ac.th/">
#                  KMITL Prince of Chumphon Campus
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="dropdown-item menu-item--expanded dropdown">
#               <span aria-expanded="false" aria-haspopup="true" class="dropdown-toggle nav-link-" data-bs-toggle="dropdown">
#
span aria-expanded="false" aria-haspopup="true" class="dropdown-toggle nav-link-" data-bs-toggle="dropdown">
#                Campus Action
#               </span>
#               <ul class="dropdown-menu">
#                <li class="dropdown-item">
#                 <a class="nav-link--indexphp-energy" data-drupal-link-system-path="node/223" href="/index.php/energy">
#                  Energy
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link--indexphp-water" data-drupal-link-system-path="node/224" href="/index.php/water">
#                  Water
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link--indexphp-transportation" data-drupal-link-system-path="node/225" href="/index.php/transportation">
#                  Transportation
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link--indexphp-buildings-grounds" data-drupal-link-system-path="node/226" href="/index.php/buildings-grounds">
#                  Buildings &amp; Grounds
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link--indexphp-health-living" data-drupal-link-system-path="node/227" href="/index.php/health-living">
#                  Health &amp; Living
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link--indexphp-waste" data-drupal-link-system-path="node/228" href="/index.php/waste">
#                  Waste
#                 </a>
#                </li>
#                <li class="dropdown-item">
#                 <a class="nav-link--indexphp-education-research" data-drupal-link-system-path="node/229" href="/index.php/education-research">
#                  Education &amp; Research
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li class="dropdown-item">
#               <a class="nav-link--indexphp-kmitl-green-gallery" data-drupal-link-system-path="node/254" href="/index.php/kmitl-green-gallery">
#                KMITL Green Gallery
#               </a>
#              </li>
#             </ul>
#            </li>
#           </ul>
#           <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/navigation/menu--main.html.twig' -->
#          </nav>
#          <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/block/block--system-menu-block.html.twig' -->
#          <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/region--nowrap.html.twig' -->
#         </div>
#        </div>
#       </nav>
#      </header>
#      <div class="highlighted">
#       <aside class="section clearfix" role="complementary">
#        <!-- THEME DEBUG -->
#        <!-- THEME HOOK: 'region' -->
#        <!-- FILE NAME SUGGESTIONS:
#    x region--nowrap.html.twig
#    * region--highlighted.html.twig
#    * region.html.twig
# -->
#        <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/region--nowrap.html.twig' -->
#        <!-- THEME DEBUG -->
#        <!-- THEME HOOK: 'block' -->
#        <!-- FILE NAME SUGGESTIONS:
#    * block--kmitl-messages.html.twig
#    x block--system-messages-block.html.twig
#    * block--system.html.twig
#    * block.html.twig
# -->
#        <!-- BEGIN OUTPUT from 'core/modules/system/templates/block--system-messages-block.html.twig' -->
#        <div class="hidden" data-drupal-messages-fallback="">
#        </div>
#        <!-- END OUTPUT from 'core/modules/system/templates/block--system-messages-block.html.twig' -->
#        <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/region--nowrap.html.twig' -->
#       </aside>
#      </div>
#      <div class="layout-main-wrapper clearfix" id="main-wrapper">
#       <div class="" id="main">
#        <div>
#         <main class="main-content col" id="content" role="main">
#          <section class="section">
#           <a id="main-content" tabindex="-1">
#           </a>
#           <!-- THEME DEBUG -->
#           <!-- THEME HOOK: 'region' -->
#           <!-- FILE NAME SUGGESTIONS:
#    x region--nowrap.html.twig
#    * region--content.html.twig
#    * region.html.twig
# -->
#           <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/region--nowrap.html.twig' -->
#           <!-- THEME DEBUG -->
#           <!-- THEME HOOK: 'block' -->
#           <!-- FILE NAME SUGGESTIONS:
#    * block--kmitl-content.html.twig
#    * block--system-main-block.html.twig
#    * block--system.html.twig
#    x block.html.twig
# -->
#           <!-- BEGIN OUTPUT from 'themes/custom/kmitl/templates/block.html.twig' -->
#           <div class="block block-system block-system-main-block" id="block-kmitl-content">
#            <div class="content">
#             <!-- THEME DEBUG -->
#             <!-- THEME HOOK: 'node' -->
#             <!-- FILE NAME SUGGESTIONS:
#    * node--581--full.html.twig
#    * node--581.html.twig
#    * node--landing-page--full.html.twig
#    x node--landing-page.html.twig
#    * node--full.html.twig
#    * node.html.twig
# -->
#             <!-- BEGIN OUTPUT from 'themes/custom/kmitl/templates/node--landing-page.html.twig' -->
#             <article about="/school-engineering" class="node-581 node node--type-landing-page node--view-mode-full clearfix" data-history-node-id="581" role="article">
#              <header>
#              </header>
#              <div class="node__content clearfix">
#               <!-- THEME DEBUG -->
#               <!-- THEME HOOK: 'blb_container_wrapper' -->
#               <!-- BEGIN OUTPUT from 'modules/contrib/bootstrap_layout_builder/templates/blb-container-wrapper.html.twig' -->
#               <div class="_none">
#                <!-- THEME DEBUG -->
#                <!-- THEME HOOK: 'blb_container' -->
#                <!-- BEGIN OUTPUT from 'modules/contrib/bootstrap_layout_builder/templates/blb-container.html.twig' -->
#                <div class="container">
#                 <!-- THEME DEBUG -->
#                 <!-- THEME HOOK: 'blb_section' -->
#                 <!-- BEGIN OUTPUT from 'modules/contrib/bootstrap_layout_builder/templates/blb-section.html.twig' -->
#                 <div class="layout row layout-builder__layout">
#                  <div class="col-12">
#                   <!-- THEME DEBUG -->
#                   <!-- THEME HOOK: 'block' -->
#                   <!-- FILE NAME SUGGESTIONS:
#    * block--field-block--node--landing-page--title.html.twig
#    * block--field-block--node--landing-page.html.twig
#    * block--field-block--node.html.twig
#    * block--field-block.html.twig
#    * block--layout-builder.html.twig
#    x block.html.twig
# -->
#                   <!-- BEGIN OUTPUT from 'themes/custom/kmitl/templates/block.html.twig' -->
#                   <div class="_none block block-layout-builder block-field-blocknodelanding-pagetitle">
#                    <div class="content">
#                     <!-- THEME DEBUG -->
#                     <!-- THEME HOOK: 'field' -->
#                     <!-- FILE NAME SUGGESTIONS:
#    * field--node--title--landing-page--default.html.twig
#    * field--node--title--landing-page.html.twig
#    x field--node--title.html.twig
#    * field--node--landing-page.html.twig
#    * field--title.html.twig
#    * field--string.html.twig
#    * field.html.twig
# -->
#                     <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/field--node--title.html.twig' -->
#                     <span class="field field--name-title field--type-string field--label-hidden">
#                      School of Engineering
#                     </span>
# ...
#                     <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/image.html.twig' -->
#                     <img alt="yt" class="media__image media__element b-lazy" data-src="/sites/default/files/2021-12/150yt.png" decoding="async" height="150" loading="" src="data:image/svg+xml;charset=utf-8,%3Csvg%20xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg'%20viewBox%3D'0%200%20150%20150'%2F%3E" typeof="foaf:Image" width="150"/>
#                     <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/image.html.twig' -->
#                    </div>
#                    <!-- END OUTPUT from 'modules/contrib/blazy/templates/blazy.html.twig' -->
#                   </div>
#                  </div>
#                  <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/field.html.twig' -->
#                 </div>
#                 <!-- END OUTPUT from 'core/modules/media/templates/media.html.twig' -->
#                </a>
#               </li>
#               <li class="nav-item" style="width:36px;padding-right:6px;">
#                <a class="nav-link" href="https://twitter.com/Kmitlofficial" target="_blank">
#                 <!-- THEME DEBUG -->
#                 <!-- THEME HOOK: 'media' -->
#                 <!-- FILE NAME SUGGESTIONS:
#    * media--source-image.html.twig
#    * media--image--default.html.twig
#    * media--image.html.twig
#    * media--default.html.twig
#    x media.html.twig
# -->
#                 <!-- BEGIN OUTPUT from 'core/modules/media/templates/media.html.twig' -->
#                 <div>
#                  <!-- THEME DEBUG -->
#                  <!-- THEME HOOK: 'field' -->
#                  <!-- FILE NAME SUGGESTIONS:
#    * field--media--field-media-image--image.html.twig
#    * field--media--field-media-image.html.twig
#    * field--media--image.html.twig
#    * field--field-media-image.html.twig
#    * field--image.html.twig
#    x field.html.twig
# -->
#                  <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/field.html.twig' -->
#                  <div class="blazy blazy--field blazy--field-media-image blazy--field-media-image--default field field--name-field-media-image field--type-image field--label-visually_hidden" data-blazy="">
#                   <div class="field__label visually-hidden">
#                    Image
#                   </div>
#                   <div class="field__item">
#                    <!-- THEME DEBUG -->
#                    <!-- THEME HOOK: 'blazy' -->
#                    <!-- BEGIN OUTPUT from 'modules/contrib/blazy/templates/blazy.html.twig' -->
#                    <div class="media media--blazy media--bundle--image is-b-loading media--image">
#                     <!-- THEME DEBUG -->
#                     <!-- THEME HOOK: 'image' -->
#                     <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/image.html.twig' -->
#                     <img alt="tw" class="media__image media__element b-lazy" data-src="/sites/default/files/2021-12/150tw.png" decoding="async" height="150" loading="" src="data:image/svg+xml;charset=utf-8,%3Csvg%20xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg'%20viewBox%3D'0%200%20150%20150'%2F%3E" typeof="foaf:Image" width="150"/>
#                     <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/image.html.twig' -->
#                    </div>
#                    <!-- END OUTPUT from 'modules/contrib/blazy/templates/blazy.html.twig' -->
#                   </div>
#                  </div>
#                  <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/field.html.twig' -->
#                 </div>
#                 <!-- END OUTPUT from 'core/modules/media/templates/media.html.twig' -->
#                </a>
#               </li>
#               <li class="nav-item" style="width:36px;padding-right:6px;">
#                <a class="nav-link" href="https://www.instagram.com/kmitlofficial" target="_blank">
#                 <!-- THEME DEBUG -->
#                 <!-- THEME HOOK: 'media' -->
#                 <!-- FILE NAME SUGGESTIONS:
#    * media--source-image.html.twig
#    * media--image--default.html.twig
#    * media--image.html.twig
#    * media--default.html.twig
#    x media.html.twig
# -->
#                 <!-- BEGIN OUTPUT from 'core/modules/media/templates/media.html.twig' -->
#                 <div>
#                  <!-- THEME DEBUG -->
#                  <!-- THEME HOOK: 'field' -->
#                  <!-- FILE NAME SUGGESTIONS:
#    * field--media--field-media-image--image.html.twig
#    * field--media--field-media-image.html.twig
#    * field--media--image.html.twig
#    * field--field-media-image.html.twig
#    * field--image.html.twig
#    x field.html.twig
# -->
#                  <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/field.html.twig' -->
#                  <div class="blazy blazy--field blazy--field-media-image blazy--field-media-image--default field field--name-field-media-image field--type-image field--label-visually_hidden" data-blazy="">
#                   <div class="field__label visually-hidden">
#                    Image
#                   </div>
#                   <div class="field__item">
#                    <!-- THEME DEBUG -->
#                    <!-- THEME HOOK: 'blazy' -->
#                    <!-- BEGIN OUTPUT from 'modules/contrib/blazy/templates/blazy.html.twig' -->
#                    <div class="media media--blazy media--bundle--image is-b-loading media--image">
#                     <!-- THEME DEBUG -->
#                     <!-- THEME HOOK: 'image' -->
#                     <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/image.html.twig' -->
#                     <img alt="ig" class="media__image media__element b-lazy" data-src="/sites/default/files/2021-12/150ig.png" decoding="async" height="150" loading="" src="data:image/svg+xml;charset=utf-8,%3Csvg%20xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg'%20viewBox%3D'0%200%20150%20150'%2F%3E" typeof="foaf:Image" width="150"/>
#                     <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/image.html.twig' -->
#                    </div>
#                    <!-- END OUTPUT from 'modules/contrib/blazy/templates/blazy.html.twig' -->
#                   </div>
#                  </div>
#                  <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/field.html.twig' -->
#                 </div>
#                 <!-- END OUTPUT from 'core/modules/media/templates/media.html.twig' -->
#                </a>
#               </li>
#               <li class="nav-item" style="width:36px;padding-right:6px;">
#                <a class="nav-link" href="https://office.kmitl.ac.th/ita/wp-content/uploads/2019/06/qr-line-kmitl.png" target="_blank">
#                 <!-- THEME DEBUG -->
#                 <!-- THEME HOOK: 'media' -->
#                 <!-- FILE NAME SUGGESTIONS:
#    * media--source-image.html.twig
#    * media--image--default.html.twig
#    * media--image.html.twig
#    * media--default.html.twig
#    x media.html.twig
# -->
#                 <!-- BEGIN OUTPUT from 'core/modules/media/templates/media.html.twig' -->
#                 <div>
#                  <!-- THEME DEBUG -->
#                  <!-- THEME HOOK: 'field' -->
#                  <!-- FILE NAME SUGGESTIONS:
#    * field--media--field-media-image--image.html.twig
#    * field--media--field-media-image.html.twig
#    * field--media--image.html.twig
#    * field--field-media-image.html.twig
#    * field--image.html.twig
#    x field.html.twig
# -->
#                  <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/field.html.twig' -->
#                  <div class="blazy blazy--field blazy--field-media-image blazy--field-media-image--default field field--name-field-media-image field--type-image field--label-visually_hidden" data-blazy="">
#                   <div class="field__label visually-hidden">
#                    Image
#                   </div>
#                   <div class="field__item">
#                    <!-- THEME DEBUG -->
#                    <!-- THEME HOOK: 'blazy' -->
#                    <!-- BEGIN OUTPUT from 'modules/contrib/blazy/templates/blazy.html.twig' -->
#                    <div class="media media--blazy media--bundle--image is-b-loading media--image">
#                     <!-- THEME DEBUG -->
#                     <!-- THEME HOOK: 'image' -->
#                     <!-- BEGIN OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/image.html.twig' -->
#                     <img alt="line" class="media__image media__element b-lazy" data-src="/sites/default/files/2021-12/150line.png" decoding="async" height="150" loading="" src="data:image/svg+xml;charset=utf-8,%3Csvg%20xmlns%3D'http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg'%20viewBox%3D'0%200%20150%20150'%2F%3E" typeof="foaf:Image" width="150"/>
#                     <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/image.html.twig' -->
#                    </div>
#                    <!-- END OUTPUT from 'modules/contrib/blazy/templates/blazy.html.twig' -->
#                   </div>
#                  </div>
#                  <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/field.html.twig' -->
#                 </div>
#                 <!-- END OUTPUT from 'core/modules/media/templates/media.html.twig' -->
#                </a>
#               </li>
#              </ul>
#             </div>
#             <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/field/field--text-with-summary.html.twig' -->
#            </div>
#           </div>
#           <!-- END OUTPUT from 'themes/custom/kmitl/templates/block.html.twig' -->
#          </section>
#          <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/region.html.twig' -->
#         </div>
#         <div class="block-feedback">
#          <!-- Messenger ปลั๊กอินแชท Code -->
#          <div id="fb-root">
#          </div>
#          <!-- Your ปลั๊กอินแชท code -->
#          <div class="fb-customerchat" id="fb-customer-chat">
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#      <script>
#       var chatbox = document.getElementById('fb-customer-chat');
#   chatbox.setAttribute("page_id", "104890389572255" );
#   chatbox.setAttribute("attribution", "biz_inbox");
#      </script>
#      <!-- Your SDK code -->
#      <script>
#       window.fbAsyncInit = function() {
#     FB.init({
#       xfbml            : true,
#       version          : 'v12.0'
#     });
#   };
#
#   (function(d, s, id) {
#     var js, fjs = d.getElementsByTagName(s)[0];
#     if (d.getElementById(id)) return;
#     js = d.createElement(s); js.id = id;
#     js.src = 'https://connect.facebook.net/th_TH/sdk/xfbml.customerchat.js';
#     fjs.parentNode.insertBefore(js, fjs);
#   }(document, 'script', 'facebook-jssdk'));
#      </script>
#     </div>
#    </div>
#    <!-- END OUTPUT from 'themes/custom/kmitl/templates/page--landing-page.html.twig' -->
#   </div>
#   <!-- END OUTPUT from 'core/modules/system/templates/off-canvas-page-wrapper.html.twig' -->
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/581","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"google_analytics":{"account":"UA-41909381-25","trackOutbound":true,"trackMailto":true,"trackDownload":true,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip"},"eu_cookie_compliance":{"cookie_policy_version":"1.0.0","popup_enabled":true,"popup_agreed_enabled":false,"popup_hide_agreed":false,"popup_clicking_confirmation":true,"popup_scrolling_confirmation":false,"popup_html_info":"\u003Cdiv role=\u0022alertdialog\u0022 aria-labelledby=\u0022popup-text\u0022  class=\u0022eu-cookie-compliance-banner eu-cookie-compliance-banner-info eu-cookie-compliance-banner--default\u0022\u003E\n  \u003Cdiv class=\u0022popup-content info eu-cookie-compliance-content\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022 class=\u0022eu-cookie-compliance-message\u0022\u003E\n      \u003Ch2\u003EWe use cookies on this site to enhance your user experience\u003C\/h2\u003E\u003Cp\u003EBy clicking the Accept button, you agree to us doing so.\u003C\/p\u003E\n              \u003Cbutton type=\u0022button\u0022 class=\u0022find-more-button eu-cookie-compliance-more-button\u0022\u003EMore info\u003C\/button\u003E\n          \u003C\/div\u003E\n\n    \n    \u003Cdiv id=\u0022popup-buttons\u0022 class=\u0022eu-cookie-compliance-buttons\u0022\u003E\n      \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button eu-cookie-compliance-default-button\u0022\u003EAccept\u003C\/button\u003E\n          \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E","use_mobile_message":false,"mobile_popup_html_info":"\u003Cdiv role=\u0022alertdialog\u0022 aria-labelledby=\u0022popup-text\u0022  class=\u0022eu-cookie-compliance-banner eu-cookie-compliance-banner-info eu-cookie-compliance-banner--default\u0022\u003E\n  \u003Cdiv class=\u0022popup-content info eu-cookie-compliance-content\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022 class=\u0022eu-cookie-compliance-message\u0022\u003E\n      \n              \u003Cbutton type=\u0022button\u0022 class=\u0022find-more-button eu-cookie-compliance-more-button\u0022\u003EMore info\u003C\/button\u003E\n          \u003C\/div\u003E\n\n    \n    \u003Cdiv id=\u0022popup-buttons\u0022 class=\u0022eu-cookie-compliance-buttons\u0022\u003E\n      \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button eu-cookie-compliance-default-button\u0022\u003EAccept\u003C\/button\u003E\n          \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E","mobile_breakpoint":768,"popup_html_agreed":false,"popup_use_bare_css":false,"popup_height":"auto","popup_width":"100%","popup_delay":1000,"popup_link":"\/privacy-policies","popup_link_new_window":true,"popup_position":false,"fixed_top_position":true,"popup_language":"en","store_consent":false,"better_support_for_screen_readers":false,"cookie_name":"","reload_page":false,"domain":"","domain_all_sites":false,"popup_eu_only_js":false,"cookie_lifetime":100,"cookie_session":0,"set_cookie_session_zero_on_disagree":0,"disagree_do_not_show_popup":false,"method":"default","automatic_cookies_removal":true,"allowed_cookies":"","withdraw_markup":"\u003Cbutton type=\u0022button\u0022 class=\u0022eu-cookie-withdraw-tab\u0022\u003EPrivacy settings\u003C\/button\u003E\n\u003Cdiv role=\u0022alertdialog\u0022 aria-labelledby=\u0022popup-text\u0022 class=\u0022eu-cookie-withdraw-banner\u0022\u003E\n  \u003Cdiv class=\u0022popup-content info eu-cookie-compliance-content\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022 class=\u0022eu-cookie-compliance-message\u0022\u003E\n      \u003Ch2\u003EWe use cookies on this site to enhance your use ...
#   </script>
#   <script src="/sites/default/files/js/js_Gbsh9Qt1bWx80_XkzMofuC0UcIMK8aN7OWQlbyMeoYk.js">
#   </script>
#   <script src="https://unpkg.com/aos@2.3.1/dist/aos.js">
#   </script>
#   <script src="/sites/default/files/js/js_Q_rEYUcJBJyFPS7pWd5vvPLFdw-I1mDl0ewrEN8CSzc.js">
#   </script>
#   <script async="" src="https://static.addtoany.com/menu/page.js">
#   </script>
#   <script src="/sites/default/files/js/js_pSYEQuZM5-F0WKkBwLd6mpw3RJXOwJq9QVPpdZmjDYo.js">
#   </script>
#   <script src="//cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.bundle.min.js">
#   </script>
#   <script src="/sites/default/files/js/js_0Z0PuPeqtGiPWXArfwboDpPRBECbKo6L023JboxM-QM.js">
#   </script>
#   <script defer="" src="/modules/contrib/eu_cookie_compliance/js/eu_cookie_compliance.js?v=1.19">
#   </script>
#   <script src="/sites/default/files/js/js_ZhIByCTPEl15zze0lUR1-L0tKMmVyW5-CZDTjO4tVIY.js">
#   </script>
#  </body>
# </html>
# <!-- END OUTPUT from 'themes/contrib/bootstrap_barrio/templates/layout/html.html.twig' -->

# %%
df = pd.DataFrame(columns=["Faculty", "Major", "Degree", "Link"])
divs_rows = soup.find_all("div", {"class":"row three-col"})
for  row in divs_rows : 
    elements_in_row = row.find_all("p",{"class": "border border-danger p-2"})
    for ele in elements_in_row:
        #print(temp.get_text())
        temp = ele.find("a")
        link = temp.get('href')
        
        text = temp.get_text()
        print(text)
        
#         splitted_text = text.split("\n")
#         degree = splitted_text[0]
#         faculty = splitted_text[2]
#         major = splitted_text[1]
#         df =  df.append({"Faculty" : faculty, "Major":major, "Degree":degree, "Link":link},  ignore_index=True)    
        
        
        
        #print(len(splitted_text))
       
        #link = 
        #degree = 
        #faculty = 
        #Major = 

        
        
        #implicit  {"Campus", isInter}
# Out:
# วศ.บ.
# วิศวกรรมโทรคมนาคมและโครงข่าย
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมไฟฟ้า
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมอิเล็กทรอนิกส์
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมคอมพิวเตอร์
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมคอมพิวเตอร์ (ต่อเนื่อง)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมเครื่องกล
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมขนส่งทางราง
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมการวัดคุม (ต่อเนื่อง)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมเมคคาทรอนิกส์และออโตเมชัน
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมโยธา
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมโยธา (ต่อเนื่อง)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมระบบอุตสาหกรรมการเกษตร (ต่อเนื่อง)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมเกษตรอัจฉริยะ
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมเคมี
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# วิศวกรรมอุตสาหการ
# คณะวิศวกรรมศาสตร์w
# วศ.บ.
# วิศวกรรมอาหาร
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Civil Engineering (International Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Biomedical Engineering (Internation Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Software Engineering (International Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Mechanical Engineering (International Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Chemical Engineering (International Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Electrical Engineering (Internation Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Industrial Engineering and Logistics Management (International Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Computer Innovation Engineering (International Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Robotics and AI Engineering (Internation Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Energy Engineering (Internation Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B. Eng. Financial Enineering (International Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ.
# B.Eng. Engineering Management and Entrepreneurship (Internation Program)
# คณะวิศวกรรมศาสตร์
# วศ.บ
# วิศวกรรมเครื่องกล แขนงวิศวกรรมพลังงาน
# คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# วศ.บ.
# วิศวกรรมเครื่องกล แขนงวิศวกรรมเกษตรอัจฉริยะ
# คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# วศ.บ.
# วิศวกรรมหุ่นยนต์และอิเล็กทรอนิกส์อัจฉริยะ
# คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# วศ.บ
# วิศวกรรมคอมพิวเตอร์
# คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# วศ.บ.
# วิศวกรรมไฟฟ้า แขนงวิศวกรรมไฟฟ้าสื่อสาร
# คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# วศ.บ.
# วิศวกรรมไฟฟ้า แขนงวิศวกรรมอิเล็กทรอนิกส์
# คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# วศ.บ
# วิศวกรรมเครื่องกล แขนงวิศวกรรมเครื่องกล
# คณะวิศวกรรมศาสตร์ (เขตชุมพร)

# %%
df.head(100)
# Out:
# Empty DataFrame
# Columns: [Faculty, Major, Degree, Link]
# Index: []

# %%
def create_dataframe (site_url) :
    why_this = []
    data  = requests.get(site_url).text
    soup = BeautifulSoup(data, 'html.parser')
    df = pd.DataFrame(columns=["Faculty", "Major", "Link","Campus","IsInter","WhyApply","Fee","Degree"])
    divs_rows = soup.find_all("div", {"class":"row three-col"})
    for  row in divs_rows : 
        elements_in_row = row.find_all("p",{"class": "border border-danger p-2"})
        for ele in elements_in_row:
        #print(temp.get_text())
            campus  = 'KMITL'
            inter  = 'False'
            temp = ele.find("a")
            link = temp.get('href')
            text = temp.get_text()
            splitted_text = text.split("\n")
            temp3 = re.search('เขต',text)
            temp4 = re.search('Inter',text)            
            print(temp3)
            if(temp3 == None):
                campus= 'KMITL'
            else : 
                campus = 'Chumporn'
                
            if(temp4 != None) : 
                inter = "True"
            faculty = splitted_text[2]
            major = splitted_text[1]
            # Go to another page for scraping more information
            data2  = requests.get(link).text
            soup2= BeautifulSoup(data2, 'html.parser')
            temp_div = soup2.find("div", {"class":"clearfix text-formatted field field--name-field-description field--type-text-with-summary field--label-hidden field__item"})
            text_arr  = temp_div.get_text().split('\n')
            degree_txt = text_arr[0]
            degree = re.findall("\bทำ",degree_txt)
            
    
            whyapply = text_arr[1]
            fee_div = soup2.find("div",{"class":"clearfix text-formatted field field--name-field-price field--type-text field--label-hidden field__item"})
            fee = fee_div.get_text()
            
            #degree  = re.findall(degree_txt ,)
          
            #degree = splitted_text[0]
            
            df =  df.append({"Faculty" : faculty, "Major":major, "Link":link , "Campus":campus,'IsInter' : inter,'WhyApply':whyapply,"Fee":fee, "Degree":degree},  ignore_index=True)    
    return df ,why_this

# %%
temp_df ,why_this= create_dataframe(en_url)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(62, 65), match='เขต'>
# <re.Match object; span=(69, 72), match='เขต'>
# <re.Match object; span=(67, 70), match='เขต'>
# <re.Match object; span=(44, 47), match='เขต'>
# <re.Match object; span=(64, 67), match='เขต'>
# <re.Match object; span=(66, 69), match='เขต'>
# <re.Match object; span=(64, 67), match='เขต'>

# %%
temp_df.head(100)
# Out:
#                          Faculty  \
# 0              คณะวิศวกรรมศาสตร์
# 1              คณะวิศวกรรมศาสตร์
# 2              คณะวิศวกรรมศาสตร์
# 3              คณะวิศวกรรมศาสตร์
# 4              คณะวิศวกรรมศาสตร์
# 5              คณะวิศวกรรมศาสตร์
# 6              คณะวิศวกรรมศาสตร์
# 7              คณะวิศวกรรมศาสตร์
# 8              คณะวิศวกรรมศาสตร์
# 9              คณะวิศวกรรมศาสตร์
# 10             คณะวิศวกรรมศาสตร์
# 11             คณะวิศวกรรมศาสตร์
# 12             คณะวิศวกรรมศาสตร์
# 13             คณะวิศวกรรมศาสตร์
# 14            คณะวิศวกรรมศาสตร์w
# 15             คณะวิศวกรรมศาสตร์
# 16             คณะวิศวกรรมศาสตร์
# 17             คณะวิศวกรรมศาสตร์
# 18             คณะวิศวกรรมศาสตร์
# 19             คณะวิศวกรรมศาสตร์
# 20             คณะวิศวกรรมศาสตร์
# 21             คณะวิศวกรรมศาสตร์
# 22             คณะวิศวกรรมศาสตร์
# 23             คณะวิศวกรรมศาสตร์
# 24             คณะวิศวกรรมศาสตร์
# 25             คณะวิศวกรรมศาสตร์
# 26             คณะวิศวกรรมศาสตร์
# 27             คณะวิศวกรรมศาสตร์
# 28  คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# 29  คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# 30  คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# 31  คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# 32  คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# 33  คณะวิศวกรรมศาสตร์ (เขตชุมพร)
# 34  คณะวิศวกรรมศาสตร์ (เขตชุมพร)
#
#                                                 Major  \
# 0                        วิศวกรรมโทรคมนาคมและโครงข่าย
# 1                                       วิศวกรรมไฟฟ้า
# 2                              วิศวกรรมอิเล็กทรอนิกส์
# 3                                 วิศวกรรมคอมพิวเตอร์
# 4                     วิศวกรรมคอมพิวเตอร์ (ต่อเนื่อง)
# 5                                   วิศวกรรมเครื่องกล
# 6                                 วิศวกรรมขนส่งทางราง
# 7                       วิศวกรรมการวัดคุม (ต่อเนื่อง)
# 8                   วิศวกรรมเมคคาทรอนิกส์และออโตเมชัน
# 9                                        วิศวกรรมโยธา
# 10                           วิศวกรรมโยธา (ต่อเนื่อง)
# 11         วิศวกรรมระบบอุตสาหกรรมการเกษตร (ต่อเนื่อง)
# 12                              วิศวกรรมเกษตรอัจฉริยะ
# 13                                       วิศวกรรมเคมี
# 14                                  วิศวกรรมอุตสาหการ
# 15                                      วิศวกรรมอาหาร
# 16   B.Eng. Civil Engineering (International Program)
# 17  B.Eng. Biomedical Engineering (Internation Pro...
# 18  B.Eng. Software Engineering (International Pro...
# 19  B.Eng. Mechanical Engineering (International P...
# 20  B.Eng. Chemical Engineering (International Pro...
# 21  B.Eng. Electrical Engineering (Internation Pro...
# 22  B.Eng. Industrial Engineering and Logistics Ma...
# 23  B.Eng. Computer Innovation Engineering (Intern...
# 24  B.Eng. Robotics and AI Engineering (Internatio...
# 25    B.Eng. Energy Engineering (Internation Program)
# 26  B. Eng. Financial Enineering (International Pr...
# 27  B.Eng. Engineering Management and Entrepreneur...
# 28              วิศวกรรมเครื่องกล แขนงวิศวกรรมพลังงาน
# 29        วิศวกรรมเครื่องกล แขนงวิศวกรรมเกษตรอัจฉริยะ
# 30          วิศวกรรมหุ่นยนต์และอิเล็กทรอนิกส์อัจฉริยะ
# 31                                วิศวกรรมคอมพิวเตอร์
# 32             วิศวกรรมไฟฟ้า แขนงวิศวกรรมไฟฟ้าสื่อสาร
# 33           วิศวกรรมไฟฟ้า แขนงวิศวกรรมอิเล็กทรอนิกส์
# 34            วิศวกรรมเครื่องกล แขนงวิศวกรรมเครื่องกล
#
#                                    Link    Campus IsInter  \
# 0   http://www-uat.kmitl.ac.th/node/444     KMITL   False
# 1   http://www-uat.kmitl.ac.th/node/427     KMITL   False
# 2   http://www-uat.kmitl.ac.th/node/447     KMITL   False
# 3   http://www-uat.kmitl.ac.th/node/448     KMITL   False
# 4   http://www-uat.kmitl.ac.th/node/450     KMITL   False
# 5   http://www-uat.kmitl.ac.th/node/451     KMITL   False
# 6   http://www-uat.kmitl.ac.th/node/452     KMITL   False
# 7   http://www-uat.kmitl.ac.th/node/453     KMITL   False
# 8   http://www-uat.kmitl.ac.th/node/454     KMITL   False
# 9   http://www-uat.kmitl.ac.th/node/455     KMITL   False
# 10  http://www-uat.kmitl.ac.th/node/456     KMITL   False
# 11  http://www-uat.kmitl.ac.th/node/457     KMITL   False
# 12  http://www-uat.kmitl.ac.th/node/458     KMITL   False
# 13  http://www-uat.kmitl.ac.th/node/459     KMITL   False
# 14  http://www-uat.kmitl.ac.th/node/460     KMITL   False
# 15  http://www-uat.kmitl.ac.th/node/461     KMITL   False
# 16  http://www-uat.kmitl.ac.th/node/462     KMITL    True
# 17  http://www-uat.kmitl.ac.th/node/463     KMITL    True
# 18  http://www-uat.kmitl.ac.th/node/464     KMITL    True
# 19  http://www-uat.kmitl.ac.th/node/465     KMITL    True
# 20  http://www-uat.kmitl.ac.th/node/466     KMITL    True
# 21  http://www-uat.kmitl.ac.th/node/467     KMITL    True
# 22  http://www-uat.kmitl.ac.th/node/468     KMITL    True
# 23  http://www-uat.kmitl.ac.th/node/469     KMITL    True
# 24  http://www-uat.kmitl.ac.th/node/470     KMITL    True
# 25  http://www-uat.kmitl.ac.th/node/471     KMITL    True
# 26  http://www-uat.kmitl.ac.th/node/472     KMITL    True
# 27  http://www-uat.kmitl.ac.th/node/473     KMITL    True
# 28  http://www-uat.kmitl.ac.th/node/550  Chumporn   False
# 29  http://www-uat.kmitl.ac.th/node/551  Chumporn   False
# 30  http://www-uat.kmitl.ac.th/node/552  Chumporn   False
# 31  http://www-uat.kmitl.ac.th/node/553  Chumporn   False
# 32  http://www-uat.kmitl.ac.th/node/554  Chumporn   False
# 33  http://www-uat.kmitl.ac.th/node/555  Chumporn   False
# 34  http://www-uat.kmitl.ac.th/node/559  Chumporn   False
#
#                                              WhyApply      Fee Degree
# 0   1. ปัจจุบัน เทคโนโลยีสื่อสารเป็นส่วนสำคัญในการ...   27,000     []
# 1   ไฟฟ้ากำลัง เป็นสาขาที่เกี่ยวข้องกับ การผลิต กา...   25,000     []
# 2   1 หลักสูตรเดียวในประเทศไทยที่เน้นการเรียนการสอ...   25,000     []
# 3   หลักสูตรวิศวกรรมคอมพิวเตอร์มุ่งสร้างวิศวกรคอมพ...   25,000     []
# 4   ภาควิชาวิศวกรรมคอมพิวเตอร์ ดำเนินการด้านการเรี...   35,000     []
# 5   วิศวกรรมเครื่องกล (Mechanical engineering) เป็...   25,000     []
# 6   ในช่วง 10 ปีที่ผ่านมา ประเทศไทยได้มีการพัฒนาระ...   25,000     []
# 7                                                       35,000     []
# 8   ปัจจุบันเทคโนโลยีในการผลิตเครื่องจักรอัตโนมัติ...   27,000     []
# 9            เป็นหลักสูตรที่ผลิตวิศวกรโยธาที่มีคุณภาพ   27,000     []
# 10  เป็นการเรียนต่อยอดจากระดับปวส. เพื่อให้เป็นวิศ...   35,000     []
# 11  นโยบายประเทศไทย 4.0 ได้อธิบายภาพการเปลี่ยนผ่าน...   35,000     []
# 12  หลักสูตรวิศวกรรมเกษตรอัจฉริยะ เป็นหลักสูตรที่ผ...   25,000     []
# 13  หลักสูตรนี้เป็นหลักสูตรที่ผลิตวิศวกรเคมีเพื่ออ...   25,000     []
# 14  วิศวอุตสาหการเป็นวิศวกรที่รอบรู้หลายด้านเพื่อป...   27,000     []
# 15  หลักสูตรวิศวกรรมอาหาร ปีการศึกษา 2564 เน้นเพื่...   25,000     []
# 16           เป็นหลักสูตรที่ผลิตวิศวกรโยธาที่มีคุณภาพ   90,000     []
# 17  วิศวกรรมชีวการแพทย์ เป็นสาขาวิชที่นำเอาความรู้...   90,000     []
# 18  As everything around us has become more and mo...   90,000     []
# 19  Mechanical engineering is one of the oldest of...   90,000     []
# 20  “WE IMPROVE QULITY OF LIFE” CHEMICAL ENGINEERS...   90,000     []
# 21  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมไฟ...   90,000     []
# 22  IELM concerned with the development, improveme...   90,000     []
# 23  Computer Innovation Engineering is designed to...  150,000     []
# 24  Robotics and AI หลักสูตรที่เป็นเทรนค์เทคโนโลยี...   90,000     []
# 25  หลักสูตรถูกออกเเบบมาเพื่อผลิตวิศวกรพลังงานเพื่...   90,000     []
# 26  นักศึกษาในหลักสูตรจะได้ศึกษาพื้นฐานเศรษฐศาสตร์...  120,000     []
# 27  เป็นหลักสูตรที่ผลิตวิศกรที่เน้นด้านการจัดการแล...   90,000     []
# 28  ผลิตบัณฑิตทางด้านวิศวกรรมเครื่องกล ที่มีคุณลัก...   20,000     []
# 29  เพื่อผลิตบัณฑิตที่มีทักษะ คิดวิเคราะห์ แก้ปัญห...   20,000     []
# 30  หลักสูตรที่มีความโดดเด่น มีเอกลักษณ์นักศึกษาสา...   20,000     []
# 31  มีความรู้ทางคณิตศาสตร์ วิทยาศาสตร์ ที่เป็นพื้น...   20,000     []
# 32  สาขาวิชาวิศวกรรมไฟฟ้านี้ถูกพัฒนาขึ้นให้สอดคล้อ...   20,000     []
# 33  สามารถออกแบบระบบงาน หรือกระบวนการทางด้านวิศวกร...   20,000     []
# 34  บัณฑิตทางด้านวิศวกรรมเครื่องกล ที่มีทักษะคิดวิ...   20,000     []

# %%
json  =temp_df.to_json(orient="records")

# %%
print(json)
# Out:
# [{"Faculty":"\u0e04\u0e13\u0e30\u0e27\u0e34\u0e28\u0e27\u0e01\u0e23\u0e23\u0e21\u0e28\u0e32\u0e2a\u0e15\u0e23\u0e4c","Major":"\u0e27\u0e34\u0e28\u0e27\u0e01\u0e23\u0e23\u0e21\u0e42\u0e17\u0e23\u0e04\u0e21\u0e19\u0e32\u0e04\u0e21\u0e41\u0e25\u0e30\u0e42\u0e04\u0e23\u0e07\u0e02\u0e48\u0e32\u0e22","Link":"http:\/\/www-uat.kmitl.ac.th\/node\/444","Campus":"KMITL","IsInter":"False","WhyApply":"1. \u0e1b\u0e31\u0e08\u0e08\u0e38\u0e1a\u0e31\u0e19 \u0e40\u0e17\u0e04\u0e42\u0e19\u0e42\u0e25\u0e22\u0e35\u0e2a\u0e37\u0e48\u0e2d\u0e2a\u0e32\u0e23\u0e40\u0e1b\u0e47\u0e19\u0e2a\u0e48\u0e27\u0e19\u0e2a\u0e33\u0e04\u0e31\u0e0d\u0e43\u0e19\u0e01\u0e32\u0e23\u0e02\u0e31\u0e1a\u0e40\u0e04\u0e25\u0e37\u0e48\u0e2d\u0e19\u0e20\u0e32\u0e04\u0e23\u0e31\u0e10\u0e41\u0e25\u0e30\u0e20\u0e32\u0e04\u0e18\u0e38\u0e23\u0e01\u0e34\u0e08 \u0e42\u0e14\u0e22\u0e08\u0e30\u0e40\u0e2b\u0e47\u0e19\u0e44\u0e14\u0e49\u0e08\u0e32\u0e01\u0e40\u0e17\u0e04\u0e42\u0e19\u0e42\u0e25\u0e22\u0e35\u0e2a\u0e37\u0e48\u0e2d\u0e2a\u0e32\u0e23 5G \u0e17\u0e35\u0e48\u0e17\u0e31\u0e48\u0e27\u0e42\u0e25\u0e01\u0e01\u0e33\u0e25\u0e31\u0e07\u0e1e\u0e31\u0e12\u0e19\u0e32\u0e2d\u0e22\u0e48\u0e32\u0e07\u0e40\u0e23\u0e48\u0e07\u0e14\u0e48\u0e27\u0e19 \u0e41\u0e25\u0e30\u0e40\u0e17\u0e04\u0e42\u0e19\u0e42\u0e25\u0e22\u0e35\u0e2a\u0e37\u0e48\u0e2d\u0e2a\u0e32\u0e23\u0e43\u0e19\u0e2d\u0e27\u0e01\u0e32\u0e28\u0e17\u0e35\u0e48\u0e1a\u0e23\u0e34\u0e29\u0e31\u0e17\u0e0a\u0e31\u0e49\u0e19\u0e19\u0e33\u0e02\u0e2d\u0e07\u0e42\u0e25\u0e01\u0e01\u0e33\u0e25\u0e31\u0e07\u0e41\u0e02\u0e48\u0e07\u0e02\u0e31\u0e19\u0e2d\u0e22\u0e48\u0e32\u0e07\u0e14\u0e38\u0e40\u0e14\u0e37\u0e2d\u0e14 2. \u0e2b\u0e25\u0e31\u0e01\u0e2a\u0e39\u0e